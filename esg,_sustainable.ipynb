# %% [markdown]
# <a href="https://colab.research.google.com/github/atakanerdogn/MY-DATA-PROJECTS/blob/main/esg%2C_sustainable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/archive (3).zip')
df.head()
# Out:
#    CompanyID CompanyName Industry         Region  Year  Revenue  ProfitMargin  \
# 0          1   Company_1   Retail  Latin America  2015    459.2           6.0
# 1          1   Company_1   Retail  Latin America  2016    473.8           4.6
# 2          1   Company_1   Retail  Latin America  2017    564.9           5.2
# 3          1   Company_1   Retail  Latin America  2018    558.4           4.3
# 4          1   Company_1   Retail  Latin America  2019    554.5           4.9
#
#    MarketCap  GrowthRate  ESG_Overall  ESG_Environmental  ESG_Social  \
# 0      337.5         NaN         57.0               60.7        33.5
# 1      366.6         3.2         56.7               58.9        32.8
# 2      313.4        19.2         56.5               57.6        34.0
# 3      283.0        -1.1         58.0               62.3        33.4
# 4      538.1        -0.7         56.6               63.7        30.0
#
#    ESG_Governance  CarbonEmissions  WaterUsage  EnergyConsumption
# ...

# %%
df = df.drop(columns=['CompanyID', 'CompanyName'])
df.head() # already dropped
# Out:
#   Industry         Region  Year  Revenue  ProfitMargin  MarketCap  GrowthRate  \
# 0   Retail  Latin America  2015    459.2           6.0      337.5         NaN
# 1   Retail  Latin America  2016    473.8           4.6      366.6         3.2
# 2   Retail  Latin America  2017    564.9           5.2      313.4        19.2
# 3   Retail  Latin America  2018    558.4           4.3      283.0        -1.1
# 4   Retail  Latin America  2019    554.5           4.9      538.1        -0.7
#
#    ESG_Overall  ESG_Environmental  ESG_Social  ESG_Governance  \
# 0         57.0               60.7        33.5            76.8
# 1         56.7               58.9        32.8            78.5
# 2         56.5               57.6        34.0            77.8
# 3         58.0               62.3        33.4            78.3
# 4         56.6               63.7        30.0            76.1
#
#    CarbonEmissions  WaterUsage  EnergyConsumption
# 0          35577.4     17788.7            71154.7
# ...

# %%
df.head()
# Out:
#   Industry         Region  Year  Revenue  ProfitMargin  MarketCap  GrowthRate  \
# 0   Retail  Latin America  2015    459.2           6.0      337.5         NaN
# 1   Retail  Latin America  2016    473.8           4.6      366.6         3.2
# 2   Retail  Latin America  2017    564.9           5.2      313.4        19.2
# 3   Retail  Latin America  2018    558.4           4.3      283.0        -1.1
# 4   Retail  Latin America  2019    554.5           4.9      538.1        -0.7
#
#    ESG_Overall  ESG_Environmental  ESG_Social  ESG_Governance  \
# 0         57.0               60.7        33.5            76.8
# 1         56.7               58.9        32.8            78.5
# 2         56.5               57.6        34.0            77.8
# 3         58.0               62.3        33.4            78.3
# 4         56.6               63.7        30.0            76.1
#
#    CarbonEmissions  WaterUsage  EnergyConsumption
# 0          35577.4     17788.7            71154.7
# ...

# %%
df.describe()
# Out:
#                Year        Revenue  ProfitMargin      MarketCap    GrowthRate  \
# count  11000.000000   11000.000000  11000.000000   11000.000000  10000.000000
# mean    2020.000000    4670.850591     10.900455   13380.622236      4.830370
# std        3.162421    9969.954369      8.758711   39922.870373      9.424787
# min     2015.000000      35.900000    -20.000000       1.800000    -36.000000
# 25%     2017.000000     938.775000      5.300000    1098.525000     -1.325000
# 50%     2020.000000    1902.300000     10.500000    3096.450000      4.900000
# 75%     2023.000000    4342.625000     16.300000    9995.500000     11.000000
# max     2025.000000  180810.400000     50.000000  865271.700000     38.000000
#
#         ESG_Overall  ESG_Environmental    ESG_Social  ESG_Governance  \
# count  11000.000000       11000.000000  11000.000000    11000.000000
# mean      54.615273          56.416991     55.660582       51.767655
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Industry           11000 non-null  object
#  1   Region             11000 non-null  object
#  2   Year               11000 non-null  int64
#  3   Revenue            11000 non-null  float64
#  4   ProfitMargin       11000 non-null  float64
#  5   MarketCap          11000 non-null  float64
#  6   GrowthRate         10000 non-null  float64
#  7   ESG_Overall        11000 non-null  float64
#  8   ESG_Environmental  11000 non-null  float64
#  9   ESG_Social         11000 non-null  float64
#  10  ESG_Governance     11000 non-null  float64
#  11  CarbonEmissions    11000 non-null  float64
#  12  WaterUsage         11000 non-null  float64
#  13  EnergyConsumption  11000 non-null  float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (11000, 14)

# %%
df.isnull().sum()
# Out:
# Industry                0
# Region                  0
# Year                    0
# Revenue                 0
# ProfitMargin            0
# MarketCap               0
# GrowthRate           1000
# ESG_Overall             0
# ESG_Environmental       0
# ESG_Social              0
# ESG_Governance          0
# CarbonEmissions         0
# WaterUsage              0
# EnergyConsumption       0
# dtype: int64

# %%
df = df.drop(columns=['GrowthRate'])
df.head()
# Out:
#   Industry         Region  Year  Revenue  ProfitMargin  MarketCap  \
# 0   Retail  Latin America  2015    459.2           6.0      337.5
# 1   Retail  Latin America  2016    473.8           4.6      366.6
# 2   Retail  Latin America  2017    564.9           5.2      313.4
# 3   Retail  Latin America  2018    558.4           4.3      283.0
# 4   Retail  Latin America  2019    554.5           4.9      538.1
#
#    ESG_Overall  ESG_Environmental  ESG_Social  ESG_Governance  \
# 0         57.0               60.7        33.5            76.8
# 1         56.7               58.9        32.8            78.5
# 2         56.5               57.6        34.0            77.8
# 3         58.0               62.3        33.4            78.3
# 4         56.6               63.7        30.0            76.1
#
#    CarbonEmissions  WaterUsage  EnergyConsumption
# 0          35577.4     17788.7            71154.7
# 1          37314.7     18657.4            74629.4
# ...

# %%
df.isnull().sum(
)
# Out:
# Industry             0
# Region               0
# Year                 0
# Revenue              0
# ProfitMargin         0
# MarketCap            0
# ESG_Overall          0
# ESG_Environmental    0
# ESG_Social           0
# ESG_Governance       0
# CarbonEmissions      0
# WaterUsage           0
# EnergyConsumption    0
# dtype: int64

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
num = df.select_dtypes(include='number')
cat = df.select_dtypes(include='object')

# %%
cat.columns
# Out:
# Index(['Industry', 'Region'], dtype='object')

# %%
num.columns
# Out:
# Index(['Year', 'Revenue', 'ProfitMargin', 'MarketCap', 'ESG_Overall',
#        'ESG_Environmental', 'ESG_Social', 'ESG_Governance', 'CarbonEmissions',
#        'WaterUsage', 'EnergyConsumption'],
#       dtype='object')

# %%
sns.countplot(x='Industry', data=cat, palette='plasma')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Region', data=cat, palette='magma')
plt.xticks(rotation=90)
plt.show()

# %%
num.columns
# Out:
# Index(['Year', 'Revenue', 'ProfitMargin', 'MarketCap', 'ESG_Overall',
#        'ESG_Environmental', 'ESG_Social', 'ESG_Governance', 'CarbonEmissions',
#        'WaterUsage', 'EnergyConsumption'],
#       dtype='object')

# %%
sns.histplot(x='Revenue', data=num, color='red')
plt.show()

# %%
sns.histplot(x='ProfitMargin', data=num, color='green')
plt.show()

# %%
sns.histplot(x='MarketCap', data=num, color='blue')
plt.show()

# %%
sns.histplot(x='ESG_Overall', data=num, color='orange')
plt.show()

# %%
sns.histplot(x='ESG_Environmental', data=num, color='purple')
plt.show()

# %%
sns.histplot(x='ESG_Social', data=num, color='yellow')
plt.show()

# %%
sns.histplot(x='ESG_Governance', data=num, color='pink')
plt.show()

# %%
sns.barplot(x='Industry', y='Revenue', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='Industry', y='ProfitMargin', data=df, color='green')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='Industry', y='MarketCap', data=df, color = 'red')
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['Industry', 'Region', 'Year', 'Revenue', 'ProfitMargin', 'MarketCap',
#        'ESG_Overall', 'ESG_Environmental', 'ESG_Social', 'ESG_Governance',
#        'CarbonEmissions', 'WaterUsage', 'EnergyConsumption'],
#       dtype='object')

# %%
revenue_year = df.groupby('Year')['Revenue'].mean()
revenue_year

revenue_year.plot(kind='line', color='red')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.show(
)

# %%
revenue_industry = df.groupby('Industry')['Revenue'].mean()
revenue_industry
revenue_industry.plot(kind='bar', color='green')
plt.xlabel('Industry')
plt.ylabel('Revenue')
plt.show()

# %%
revenue_region = df.groupby('Region')['Revenue'].mean().plot(kind='bar', color='blue')
plt.xlabel('Region')
plt.ylabel('Revenue')
plt.show()

# %%
df.columns
# Out:
# Index(['Industry', 'Region', 'Year', 'Revenue', 'ProfitMargin', 'MarketCap',
#        'ESG_Overall', 'ESG_Environmental', 'ESG_Social', 'ESG_Governance',
#        'CarbonEmissions', 'WaterUsage', 'EnergyConsumption'],
#       dtype='object')

# %%
ProfitMargin_MarketCap = df.groupby('ProfitMargin')['MarketCap'].mean()
ProfitMargin_MarketCap
ProfitMargin_MarketCap.plot(kind='bar', color='orange')
plt.xlabel('ProfitMargin')
plt.ylabel('MarketCap')
plt.xticks([])
plt.show()

# %%
esgoverall_esgsocial = df.groupby('ESG_Social')['ESG_Overall'].mean()
esgoverall_esgsocial
esgoverall_esgsocial.plot(kind='bar', color='purple')
plt.xlabel('ESG_Social')
plt.ylabel('ESG_Overall')
plt.xticks([])
plt.show()

# %%
carbon_vs_energy = df.groupby('CarbonEmissions')['EnergyConsumption'].mean()
sns.lineplot(carbon_vs_energy)
plt.xlabel('CarbonEmmisions')
plt.ylabel('EnergyConsumption')
plt.show()

# %%
sns.lineplot(x='CarbonEmissions', y='EnergyConsumption', data=df, color='green')
plt.show()

# %%
# carbon emission through the years

sns.lineplot(x='Year', y='CarbonEmissions', data=df, color='red')
plt.show()

# %%
sns.lineplot(x='Year', y='ESG_Overall', data=df, color='blue')
plt.show()

# %%
sns.lineplot(x='Year', y='ESG_Environmental', data=df, color='orange')
plt.show()

# %%
sns.lineplot(x='Year', y='MarketCap', data=df, color='purple')
plt.show()

# %%
sns.lineplot(x='Year', y='Revenue', data=df, color='red')
plt.show()

# %%
corr_matrix = num.corr()
corr_matrix
# Out:
#                        Year   Revenue  ProfitMargin  MarketCap  ESG_Overall  \
# Year               1.000000  0.102280     -0.002463   0.083379     0.127865
# Revenue            0.102280  1.000000      0.132488   0.836884     0.148869
# ProfitMargin      -0.002463  0.132488      1.000000   0.259927     0.088006
# MarketCap          0.083379  0.836884      0.259927   1.000000     0.143793
# ESG_Overall        0.127865  0.148869      0.088006   0.143793     1.000000
# ESG_Environmental  0.108934  0.206628      0.218662   0.214595     0.568171
# ESG_Social         0.070838  0.047173     -0.032642   0.039297     0.662357
# ESG_Governance     0.060352  0.018489     -0.035372   0.007758     0.671476
# CarbonEmissions    0.045494  0.507967     -0.006027   0.299603    -0.039672
# WaterUsage         0.060332  0.540424     -0.002967   0.319704    -0.042911
# EnergyConsumption  0.040761  0.476501     -0.010356   0.268541    -0.043649
#
# ...

# %%
corr_matrix.shape
# Out:
# (11, 11)

# %%
plt.figure(figsize=(11,11))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
stats = {'Mode: ': num.mean(),
         'Median: ': num.median(),
         'Standard Deviation: ': num.std(),
         'Variance': num.var(),
         'Kurtosis': num.kurt(),
         'Skewness': num.skew()}
stats
# Out:
# {'Mode: ': Year                 2.020000e+03
#  Revenue              4.670851e+03
#  ProfitMargin         1.090045e+01
#  MarketCap            1.338062e+04
#  ESG_Overall          5.461527e+01
#  ESG_Environmental    5.641699e+01
#  ESG_Social           5.566058e+01
#  ESG_Governance       5.176765e+01
#  CarbonEmissions      1.271462e+06
#  WaterUsage           5.600442e+05
#  EnergyConsumption    1.165839e+07
#  dtype: float64,
#  'Median: ': Year                    2020.00
#  Revenue                 1902.30
#  ProfitMargin              10.50
#  MarketCap               3096.45
#  ESG_Overall               54.60
#  ESG_Environmental         55.60
#  ESG_Social                55.15
#  ESG_Governance            52.10
#  CarbonEmissions       292073.45
#  WaterUsage            203880.45
#  EnergyConsumption    1221745.45
#  dtype: float64,
#  'Standard Deviation: ': Year                 3.162421e+00
#  Revenue              9.969954e+03
#  ProfitMargin         8.758711e+00
# ...

# %%
# z test

# %%
num.columns
# Out:
# Index(['Year', 'Revenue', 'ProfitMargin', 'MarketCap', 'ESG_Overall',
#        'ESG_Environmental', 'ESG_Social', 'ESG_Governance', 'CarbonEmissions',
#        'WaterUsage', 'EnergyConsumption'],
#       dtype='object')

# %%
cat.columns
# Out:
# Index(['Industry', 'Region'], dtype='object')

# %%
df['Industry'].unique()
# Out:
# array(['Retail', 'Transportation', 'Technology', 'Finance', 'Healthcare',
#        'Energy', 'Consumer Goods', 'Utilities', 'Manufacturing'],
#       dtype=object)

# %%
finance = df[df['Industry'] == 'Finance']
finance

sns.countplot(y='Region', data=finance, palette='crest')
plt.tight_layout()
plt.title('Finance')
plt.xticks(rotation=90)
plt.show()

# %%
healthcare = df[df['Industry'] == 'Healthcare']
healthcare

sns.countplot(y='Region', data=healthcare, palette='magma')
plt.title('Heathcare')
plt.tight_layout()

plt.show()

# %%
energy = df[df['Industry'] == 'Energy']

sns.countplot(y='Region', data=energy, palette='plasma')
plt.tight_layout()

plt.show()

# %%
retail = df[df['Industry'] == 'Retail']

sns.countplot(y='Region', data=retail, palette='rocket')
plt.tight_layout()

plt.show()

# %%
consumer_goods = df[df['Industry'] == 'Consumer Goods']

sns.countplot(y='Region', data=consumer_goods, palette='crest')
plt.tight_layout()

plt.show()

# %%
transportation = df[df['Industry'] == 'Transportation']

sns.countplot(y='Region', data=transportation, palette='Set1')
plt.tight_layout()

plt.show()

# %%
df.columns
# Out:
# Index(['Industry', 'Region', 'Year', 'Revenue', 'ProfitMargin', 'MarketCap',
#        'ESG_Overall', 'ESG_Environmental', 'ESG_Social', 'ESG_Governance',
#        'CarbonEmissions', 'WaterUsage', 'EnergyConsumption'],
#       dtype='object')

# %%
df['CarbonEmissions'].unique()
carbon_water = df.groupby('CarbonEmissions')['WaterUsage'].mean()
sns.histplot(carbon_water)
plt.show()
