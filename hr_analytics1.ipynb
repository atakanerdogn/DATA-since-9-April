# %% [markdown]
# <a href="https://colab.research.google.com/github/atakanerdogn/Data-Analysis-and-Science-Projects/blob/main/hr_analytics1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/1738816646605_be86fcd688aa6903.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
num = df.select_dtypes(include=np.number)
cat = df.select_dtypes(include='object')

# %%
num.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60])

# %%
cat.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
sns.countplot(x='Attrition', data=df, hue='BusinessTravel', palette='Set2')
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x='Attrition', data=df, hue='Department', palette='mako')
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x='Attrition', data=df, hue='EducationField', palette='mako')
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x='Attrition', data=df, hue='Gender', palette='mako')
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(y='JobRole', data=df, hue='Attrition', palette='mako')
plt.xticks(rotation=90)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  [Text(0.0, 0, '0'),
#   Text(50.0, 0, '50'),
#   Text(100.0, 0, '100'),
#   Text(150.0, 0, '150'),
#   Text(200.0, 0, '200'),
#   Text(250.0, 0, '250'),
#   Text(300.0, 0, '300')])

# %%
cat.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
sns.countplot(x='EducationField', data=df, hue='JobRole', palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Life Sciences'),
#   Text(1, 0, 'Other'),
#   Text(2, 0, 'Medical'),
#   Text(3, 0, 'Marketing'),
#   Text(4, 0, 'Technical Degree'),
#   Text(5, 0, 'Human Resources')])

# %%
sns.countplot(x='JobRole', data=df, hue='BusinessTravel', palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.barplot(x='JobRole', y='MonthlyIncome', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
sns.barplot(x='JobRole', y='Age', data=df, palette='mako')
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.barplot(x='JobRole', y='HourlyRate', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
sns.barplot(x='JobRole', y='JobInvolvement', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
sns.barplot(x='JobRole', y='MonthlyRate', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
sns.barplot(x='JobRole', y='PercentSalaryHike', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
sns.barplot(x='JobRole', y='JobSatisfaction', data=df, palette='magma')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.plot(kind='scatter', x='Age', y='MonthlyIncome', color='red')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %%
df.plot(kind='scatter', x='Age', y='MonthlyIncome', color='blue')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %%
df.plot(kind='scatter', x='Age', y='YearsAtCompany', color='green')
# Out:
# <Axes: xlabel='Age', ylabel='YearsAtCompany'>

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
plt.pie(df['Attrition'].value_counts(), labels=df['Attrition'].value_counts().index, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x78b219eb6790>,
# ...
#  [Text(-0.9618917098664642, 0.5336331497294465, 'No'),
#   Text(0.9618917565181541, -0.5336330656381971, 'Yes')],
#  [Text(-0.5246682053817077, 0.29107262712515264, '83.88%'),
#   Text(0.524668230828084, -0.2910725812571984, '16.12%')])

# %%
plt.pie(df['Gender'].value_counts(), labels = df['Gender'].value_counts().index, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x78b216a3a310>,
# ...
#  [Text(-0.339918873399729, 1.0461621095732052, 'Male'),
#   Text(0.33991884014588697, -1.0461621203780394, 'Female')],
#  [Text(-0.18541029458167035, 0.570633877949021, '60.00%'),
#   Text(0.18541027644321104, -0.5706338838425669, '40.00%')])

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# job role, department and job satisfaction

jds = df.groupby(['JobRole', 'Department'])['JobSatisfaction'].value_counts()
jds
# Out:
# JobRole                    Department              JobSatisfaction
# Healthcare Representative  Research & Development  3                   43
#                                                    4                   43
#                                                    1                   26
#                                                    2                   19
# Human Resources            Human Resources         2                   16
#                                                    3                   13
#                                                    4                   13
#                                                    1                   10
# Laboratory Technician      Research & Development  4                   80
#                                                    3                   75
#                                                    1                   56
#                                                    2                   48
# ...

# %%
# years in current role vs job satisfaction vs yearssince last promotion vs years at company vs years with current manager

yyy = df.groupby(['Department', 'YearsInCurrentRole', 'JobSatisfaction', 'YearsSinceLastPromotion', 'YearsAtCompany', 'YearsWithCurrManager'])[['Attrition','JobSatisfaction']].value_counts()
yyy
# Out:
# Department       YearsInCurrentRole  JobSatisfaction  YearsSinceLastPromotion  YearsAtCompany  YearsWithCurrManager  Attrition
# Human Resources  0                   1                0                        1               0                     Yes          1
#                                      2                0                        1               0                     No           1
#                                                                                                                      Yes          1
#                                                       1                        2               2                     No           1
#                                                       4                        10              7                     No           1
#                                                                                                                                  ..
# ...

# %%
# distance from home, jobsatisfaction,jobrole

jdf = df.groupby(['DistanceFromHome', 'JobSatisfaction', 'JobRole'])[['Attrition']].value_counts()
jdf
# Out:
# DistanceFromHome  JobSatisfaction  JobRole                    Attrition
# 1                 1                Healthcare Representative  No           6
#                                    Human Resources            No           1
#                                                               Yes          1
#                                    Laboratory Technician      No           5
#                                                               Yes          1
#                                                                           ..
# 29                4                Manager                    No           1
#                                    Manufacturing Director     No           2
#                                    Research Scientist         No           2
#                                    Sales Executive            No           1
#                                    Sales Representative       No           1
# Name: count, Length: 708, dtype: int64

# %%
# work life balance vs distance from home vs job satisfaction

wlb = df.groupby(['WorkLifeBalance', 'DistanceFromHome'])[['JobSatisfaction']].value_counts()
wlb
# Out:
# WorkLifeBalance  DistanceFromHome  JobSatisfaction
# 1                1                 3                  4
#                                    1                  3
#                                    4                  3
#                                    2                  2
#                  2                 3                  4
#                                                      ..
# 4                28                2                  1
#                                    4                  1
#                  29                1                  1
#                                    2                  1
#                                    4                  1
# Name: count, Length: 331, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#education, num companies worked, hourly rate

edu = df.groupby(['Education', 'NumCompaniesWorked'])[['HourlyRate']].value_counts()
edu
# Out:
# Education  NumCompaniesWorked  HourlyRate
# 1          0                   36            2
#                                52            2
#                                66            2
#                                69            2
#                                73            2
#                                             ..
# 5          6                   92            1
#            7                   79            2
#                                91            1
#                                99            1
#            9                   63            1
# Name: count, Length: 980, dtype: int64

# %%
# standart hours, job satisfaction, performance rating

sjp = df.groupby(['StandardHours', 'JobSatisfaction'])[['PerformanceRating']].value_counts()
sjp
# Out:
# StandardHours  JobSatisfaction  PerformanceRating
# 80             1                3                    241
#                                 4                     48
#                2                3                    237
#                                 4                     43
#                3                3                    386
#                                 4                     56
#                4                3                    380
#                                 4                     79
# Name: count, dtype: int64

# %%
num.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
num_selected = ['JobSatisfaction', 'YearsWithCurrManager', 'NumCompaniesWorked', 'PercentSalaryHike','PerformanceRating','TotalWorkingYears','Education']
num_selected_df = df[num_selected]
num_selected_df.head()
# Out:
#    JobSatisfaction  YearsWithCurrManager  NumCompaniesWorked  \
# 0                4                     5                   8
# 1                2                     7                   1
# 2                3                     0                   6
# 3                3                     0                   1
# 4                2                     2                   9
#
#    PercentSalaryHike  PerformanceRating  TotalWorkingYears  Education
# 0                 11                  3                  8          2
# 1                 23                  4                 10          1
# 2                 15                  3                  7          2
# 3                 11                  3                  8          4
# 4                 12                  3                  6          1

# %%
sns.pairplot(num_selected_df, hue='JobSatisfaction')

# %%
corr_matrixx = num_selected_df.corr()
corr_matrixx.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_9b868_row0_col0, #T_9b868_row1_col1, #T_9b868_row2_col2, #T_9b868_row3_col3, #T_9b868_row4_col4, #T_9b868_row5_col5, #T_9b868_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9b868_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_9b868_row0_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9b868_row0_col3, #T_9b868_row6_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9b868_row0_col4, #T_9b868_row1_col0, #T_9b868_row4_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_9b868_row0_col5, #T_9b868_row1_col2, #T_9b868_row2_col0, #T_9b868_row2_col1, #T_9b868_row3_col5, #T_9b868_row4_col6, #T_9b868_row5_col3, #T_9b868_row6_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9b868_row0_col6, #T_9b868_row3_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_9b868_row1_col3, #T_9b868_row2_col3, #T_9b868_row2_col4, #T_9b868_row6_col3 {
# ...

# %%
corr_matrix_general = num.corr()
corr_matrix_general.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_1ea19_row0_col0, #T_1ea19_row1_col1, #T_1ea19_row2_col2, #T_1ea19_row3_col3, #T_1ea19_row5_col5, #T_1ea19_row6_col6, #T_1ea19_row7_col7, #T_1ea19_row8_col8, #T_1ea19_row9_col9, #T_1ea19_row10_col10, #T_1ea19_row11_col11, #T_1ea19_row12_col12, #T_1ea19_row13_col13, #T_1ea19_row14_col14, #T_1ea19_row15_col15, #T_1ea19_row16_col16, #T_1ea19_row18_col18, #T_1ea19_row19_col19, #T_1ea19_row20_col20, #T_1ea19_row21_col21, #T_1ea19_row22_col22, #T_1ea19_row23_col23, #T_1ea19_row24_col24, #T_1ea19_row25_col25 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# ...

# %%
df.dropna()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
num = df.select_dtypes(include='number')
cat = df.select_dtypes(include='object')

num = num.drop(columns=['EmployeeCount','StandardHours'])

df = pd.concat([num, cat], axis=1)
df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0   41       1102                 1          2               1
# 1   49        279                 8          1               2
# 2   37       1373                 2          2               4
# 3   33       1392                 3          4               5
# 4   27        591                 2          1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  YearsWithCurrManager  Attrition     BusinessTravel  \
# 0                4  ...                     5        Yes      Travel_Rarely
# ...

# %%
num.corr().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_4490a_row0_col0, #T_4490a_row1_col1, #T_4490a_row2_col2, #T_4490a_row3_col3, #T_4490a_row4_col4, #T_4490a_row5_col5, #T_4490a_row6_col6, #T_4490a_row7_col7, #T_4490a_row8_col8, #T_4490a_row9_col9, #T_4490a_row10_col10, #T_4490a_row11_col11, #T_4490a_row12_col12, #T_4490a_row13_col13, #T_4490a_row14_col14, #T_4490a_row15_col15, #T_4490a_row16_col16, #T_4490a_row17_col17, #T_4490a_row18_col18, #T_4490a_row19_col19, #T_4490a_row20_col20, #T_4490a_row21_col21, #T_4490a_row22_col22, #T_4490a_row23_col23 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %%
df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0   41       1102                 1          2               1
# 1   49        279                 8          1               2
# 2   37       1373                 2          2               4
# 3   33       1392                 3          4               5
# 4   27        591                 2          1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  YearsWithCurrManager  Attrition     BusinessTravel  \
# 0                4  ...                     5        Yes      Travel_Rarely
# ...

# %%
# education and job satisfaction

ej = df.groupby('Education')['JobSatisfaction'].value_counts()
ej

ej_df = pd.DataFrame(ej)
ej_df

ej.plot(kind='bar')
plt.xlabel('Education, JobSatisfaction')
plt.ylabel('count')
plt.title('Education and Job Satisfaction')
plt.show()

# %%
sns.barplot(x='Education', y='JobSatisfaction', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, '1'),
#   Text(1, 0, '2'),
#   Text(2, 0, '3'),
#   Text(3, 0, '4'),
#   Text(4, 0, '5')])

# %%
rd = df[df['Department'] == 'Research & Development']
rd.plot(kind='scatter', x='Age', y='MonthlyIncome', color='red')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %%
rd2 = rd.sample(20)
rd2.plot(kind='bar', x='MonthlyIncome', y='Age', color='blue')
# Out:
# <Axes: xlabel='MonthlyIncome'>

# %%
cat.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
sns.countplot(x='JobRole', hue='Gender', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
sns.countplot(x='JobRole', hue='Attrition', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
sns.countplot(x='Gender', hue='MaritalStatus', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1], [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
sns.countplot(x='MaritalStatus', hue='Attrition', data=df, palette='Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Single'), Text(1, 0, 'Married'), Text(2, 0, 'Divorced')])

# %%
num.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.histplot(x='MonthlyIncome', data=df, color='red')
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Count'>

# %%
sns.histplot(x='TotalWorkingYears', data=df, color='blue')
# Out:
# <Axes: xlabel='TotalWorkingYears', ylabel='Count'>

# %%
sns.histplot(x='Age', data=df, color='green')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='YearsAtCompany', data=df, color='orange')
sns.histplot(x='YearsInCurrentRole', data=df, color='purple')
sns.histplot(x='YearsWithCurrManager', data=df, color='yellow')
# Out:
# <Axes: xlabel='YearsAtCompany', ylabel='Count'>

# %%
sns.histplot(x='DistanceFromHome', data=df, color='red')
# Out:
# <Axes: xlabel='DistanceFromHome', ylabel='Count'>
