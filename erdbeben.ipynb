# %% [markdown]
# <a href="https://colab.research.google.com/github/atakanerdogn/MY-PROJECTS-DATA-ANALYSIS/blob/main/erdbeben.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This data set is taken from USGS(U.S Geological Survey). The USGS provides reliable scientific information to describe and understand the Earth; minimize loss of life and property from natural disasters; manage water, biological, energy, and mineral resources; and enhance and protect our quality of life.
#
# As part of it's program, USGS monitors and reports on earthquakes, assesses earthquake impacts and hazards, and conducts targeted research on the causes and effects of earthquakes. The USGS provides real-time notifications, feeds and web services about earthquakes just after they happen. Further details can be found in the link below,
#
# https://earthquake.usgs.gov/earthquakes/feed/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('all_month.csv')
df.head()
# Out:
#                        time   latitude   longitude    depth   mag magType  \
# 0  2025-04-11T02:32:21.880Z  38.831501 -122.801331   1.6700  0.76      md
# 1  2025-04-11T02:29:25.830Z  33.711000 -116.816833  17.0900  1.09      ml
# 2  2025-04-11T02:28:36.790Z  35.339167 -117.809833   7.0800  2.01      ml
# 3  2025-04-11T02:26:33.780Z  37.195999 -122.114998   9.8100  1.13      md
# 4  2025-04-11T02:26:00.900Z  31.923000 -103.841000   6.3654  2.10      ml
#
#     nst    gap     dmin   rms  ...                   updated  \
# 0  10.0   68.0  0.01059  0.01  ...  2025-04-11T02:33:59.470Z
# 1  28.0   65.0  0.08482  0.16  ...  2025-04-11T02:32:57.425Z
# 2  46.0   36.0  0.07740  0.18  ...  2025-04-11T02:32:09.703Z
# 3   8.0  110.0  0.10190  0.13  ...  2025-04-11T02:28:08.628Z
# 4  12.0  103.0  0.00000  0.20  ...  2025-04-11T02:33:05.396Z
#
#                            place        type horizontalError depthError  \
# 0           7 km WNW of Cobb, CA  earthquake            0.33   0.620000
# ...

# %%
df['type'].nunique()
# Out:
# 4

# %%
df['type'].unique()
# Out:
# array(['earthquake', 'explosion', 'quarry blast', 'ice quake'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10054 entries, 0 to 10053
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             10054 non-null  object
#  1   latitude         10054 non-null  float64
#  2   longitude        10054 non-null  float64
#  3   depth            10054 non-null  float64
#  4   mag              10054 non-null  float64
#  5   magType          10054 non-null  object
#  6   nst              8424 non-null   float64
#  7   gap              8424 non-null   float64
#  8   dmin             8424 non-null   float64
#  9   rms              10053 non-null  float64
#  10  net              10054 non-null  object
#  11  id               10054 non-null  object
#  12  updated          10054 non-null  object
#  13  place            10054 non-null  object
#  14  type             10054 non-null  object
#  15  horizontalError  7746 non-null   float64
# ...

# %%
df.describe()
# Out:
#            latitude     longitude         depth           mag          nst  \
# count  10054.000000  10054.000000  10054.000000  10054.000000  8424.000000
# mean      39.518399   -109.690834     20.883365      1.505934    23.053538
# std       18.642960     68.750423     55.559267      1.301020    22.807264
# min      -65.070900   -179.995100     -3.500000     -1.740000     0.000000
# 25%       33.787375   -149.604750      2.580000      0.720000     9.000000
# 50%       38.821835   -122.181000      7.003400      1.300000    16.000000
# 75%       51.927625   -113.797083     13.737500      1.977500    28.000000
# max       85.789900    179.928300    645.749000      7.700000   324.000000
#
#                gap         dmin           rms  horizontalError    depthError  \
# count  8424.000000  8424.000000  10053.000000      7746.000000  10053.000000
# mean    115.377614     0.482103      0.260463         1.712134      2.171126
# ...

# %%
df.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                1630
# gap                1630
# dmin               1630
# rms                   1
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2308
# depthError            1
# magError           1652
# magNst             1634
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
df.fillna(0, inplace=True)
df.isnull().sum()
# Out:
# time               0
# latitude           0
# longitude          0
# depth              0
# mag                0
# magType            0
# nst                0
# gap                0
# dmin               0
# rms                0
# net                0
# id                 0
# updated            0
# place              0
# type               0
# horizontalError    0
# depthError         0
# magError           0
# magNst             0
# status             0
# locationSource     0
# magSource          0
# dtype: int64

# %%
df.shape
# Out:
# (10054, 22)

# %%
num = df.select_dtypes(include=np.number)
num.head()
cat = df.select_dtypes(include=object)
cat.head()
# Out:
#                        time magType net          id                   updated  \
# 0  2025-04-11T02:32:21.880Z      md  nc  nc75163371  2025-04-11T02:33:59.470Z
# 1  2025-04-11T02:29:25.830Z      ml  ci  ci40922031  2025-04-11T02:32:57.425Z
# 2  2025-04-11T02:28:36.790Z      ml  ci  ci40922023  2025-04-11T02:32:09.703Z
# 3  2025-04-11T02:26:33.780Z      md  nc  nc75163361  2025-04-11T02:28:08.628Z
# 4  2025-04-11T02:26:00.900Z      ml  tx  tx2025haxe  2025-04-11T02:33:05.396Z
#
#                            place        type     status locationSource  \
# 0           7 km WNW of Cobb, CA  earthquake  automatic             nc
# 1    8 km ESE of Valle Vista, CA  earthquake  automatic             ci
# 2  16 km WSW of Johannesburg, CA  earthquake  automatic             ci
# 3  8 km NNE of Boulder Creek, CA  earthquake  automatic             nc
# 4     33 km NW of Mentone, Texas  earthquake  automatic             tx
#
#   magSource
# 0        nc
# 1        ci
# 2        ci
# 3        nc
# ...

# %%
num
# Out:
#         latitude   longitude     depth   mag   nst    gap      dmin   rms  \
# 0      38.831501 -122.801331    1.6700  0.76  10.0   68.0  0.010590  0.01
# 1      33.711000 -116.816833   17.0900  1.09  28.0   65.0  0.084820  0.16
# 2      35.339167 -117.809833    7.0800  2.01  46.0   36.0  0.077400  0.18
# 3      37.195999 -122.114998    9.8100  1.13   8.0  110.0  0.101900  0.13
# 4      31.923000 -103.841000    6.3654  2.10  12.0  103.0  0.000000  0.20
# ...          ...         ...       ...   ...   ...    ...       ...   ...
# 10049  33.595667 -116.874500    5.5600  0.93  43.0   30.0  0.040850  0.17
# 10050 -21.568000  169.329600   46.2040  4.70  56.0  108.0  2.033000  0.89
# 10051  35.527833  -96.773333    5.2600 -0.73  10.0  188.0  0.007199  0.02
# 10052  64.106000 -148.355800  114.1000  1.40   0.0    0.0  0.000000  0.52
# 10053  38.831001 -122.817665    2.4300  0.72   7.0  151.0  0.009636  0.01
#
#        horizontalError  depthError  magError  magNst
# ...

# %%
sns.scatterplot(x='latitude', y='longitude', data=df, hue='mag', palette = 'crest')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
sns.histplot(df['mag'], kde=True)
plt.show()

# %%
sns.histplot(df['depth'], kde=True)
plt.show()

# %%
sns.histplot(df['magType'], kde=True)
plt.show()

# %%
num.columns
# Out:
# Index(['latitude', 'longitude', 'depth', 'mag', 'nst', 'gap', 'dmin', 'rms',
#        'horizontalError', 'depthError', 'magError', 'magNst'],
#       dtype='object')

# %%
depth_mag = num.groupby('depth')['mag'].mean()
depth_mag

sns.scatterplot(x=depth_mag.index, y=depth_mag.values)
plt.show()

# %%
sns.pairplot(num, hue='mag', diag_kind='kde')
plt.show()

# %%
num.columns
# Out:
# Index(['latitude', 'longitude', 'depth', 'mag', 'nst', 'gap', 'dmin', 'rms',
#        'horizontalError', 'depthError', 'magError', 'magNst'],
#       dtype='object')

# %%
cat.columns
# Out:
# Index(['time', 'magType', 'net', 'id', 'updated', 'place', 'type', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
#

# %%
sns.countplot(x='type', data=df, palette='crest')
plt.show()

# %%
sns.countplot(x='magType', data=df, palette='viridis')
plt.show()

# %%
sns.countplot(x='nst', data=df, palette='crest')
plt.xticks([])
plt.show()

# %%
gap = df['gap'].sample(50)

sns.countplot(x=gap, data=df)
plt.xticks(rotation=90)
plt.show()

# %%
place_mag = df.groupby('place')['mag'].mean()
place_mag = place_mag.sample(20)

sns.barplot(x=place_mag.index, y=place_mag.values)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='status', data=df)
plt.show()

# %%
sns.countplot(x='locationSource', data=df)
plt.show()
