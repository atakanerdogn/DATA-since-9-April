# %% [markdown]
# <a href="https://colab.research.google.com/github/atakanerdogn/My-Data-Analysis-Projects/blob/main/sales_dataset_from_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sales = pd.read_csv('Sales Dataset.csv')
sales.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   PaymentMode  Order Date   CustomerName     State     City Year-Month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1194 non-null   object
#  1   Amount        1194 non-null   int64
#  2   Profit        1194 non-null   int64
#  3   Quantity      1194 non-null   int64
#  4   Category      1194 non-null   object
#  5   Sub-Category  1194 non-null   object
#  6   PaymentMode   1194 non-null   object
#  7   Order Date    1194 non-null   object
#  8   CustomerName  1194 non-null   object
#  9   State         1194 non-null   object
#  10  City          1194 non-null   object
#  11  Year-Month    1194 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 112.1+ KB

# %%
sales.describe()
# Out:
#             Amount       Profit     Quantity
# count  1194.000000  1194.000000  1194.000000
# mean   5178.089615  1348.992462    10.674204
# std    2804.921955  1117.992573     5.777102
# min     508.000000    50.000000     1.000000
# 25%    2799.000000   410.000000     6.000000
# 50%    5152.000000  1014.000000    11.000000
# 75%    7626.000000  2035.000000    16.000000
# max    9992.000000  4930.000000    20.000000

# %%
sales.tail()
# Out:
#      Order ID  Amount  Profit  Quantity         Category Sub-Category  \
# 1189  B-26370    8825    3594        15        Furniture       Tables
# 1190  B-26298    2082     642         8      Electronics       Phones
# 1191  B-26298    2082     642         8      Electronics       Phones
# 1192  B-26298    2082     642         8      Electronics       Phones
# 1193  B-25068     914     163        13  Office Supplies      Markers
#
#      PaymentMode  Order Date        CustomerName     State           City  \
# 1189  Debit Card  2024-07-31        Megan Mclean  New York  New York City
# 1190         EMI  2020-06-02        Caitlin Hunt  New York      Rochester
# 1191         EMI  2022-12-15       Jenna Holland     Texas         Austin
# 1192         EMI  2020-08-07  Stephanie Oconnell  New York        Buffalo
# 1193         UPI  2024-10-26         Andrea Hill  Illinois        Chicago
#
#      Year-Month
# 1189    2024-07
# 1190    2020-06
# 1191    2022-12
# 1192    2020-08
# ...

# %%
sales.shape
# Out:
# (1194, 12)

# %%
sales.dtypes
# Out:
# Order ID        object
# Amount           int64
# Profit           int64
# Quantity         int64
# Category        object
# Sub-Category    object
# PaymentMode     object
# Order Date      object
# CustomerName    object
# State           object
# City            object
# Year-Month      object
# dtype: object

# %%
num = sales.select_dtypes(include=np.number)
num.head()
# Out:
#    Amount  Profit  Quantity
# 0    9726    1275         5
# 1    9726    1275         5
# 2    9726    1275         5
# 3    4975    1330        14
# 4    4975    1330        14

# %%
cat = sales.select_dtypes(include='object')
cat.head()
# Out:
#   Order ID     Category      Sub-Category PaymentMode  Order Date  \
# 0  B-26776  Electronics  Electronic Games         UPI  2023-06-27
# 1  B-26776  Electronics  Electronic Games         UPI  2024-12-27
# 2  B-26776  Electronics  Electronic Games         UPI  2021-07-25
# 3  B-26776  Electronics          Printers         UPI  2023-06-27
# 4  B-26776  Electronics          Printers         UPI  2024-12-27
#
#     CustomerName     State     City Year-Month
# 0  David Padilla   Florida    Miami    2023-06
# 1  Connor Morgan  Illinois  Chicago    2024-12
# 2   Robert Stone  New York  Buffalo    2021-07
# 3  David Padilla   Florida    Miami    2023-06
# 4  Connor Morgan  Illinois  Chicago    2024-12

# %%
sales.isnull().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# Order Date      0
# CustomerName    0
# State           0
# City            0
# Year-Month      0
# dtype: int64

# %%
sales.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1189    False
# 1190    False
# 1191    False
# 1192    False
# 1193    False
# Length: 1194, dtype: bool

# %%
sns.swarmplot(x='State', y='Amount', data=sales, palette='magma')
# Out:
# <ipython-input-12-c13c5dad636c>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='State', y='Amount', data=sales, palette='magma')
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# Univariate Analysis

# %%
sales.columns
# Out:
# Index(['Order ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'PaymentMode', 'Order Date', 'CustomerName', 'State', 'City',
#        'Year-Month'],
#       dtype='object')

# %%
sales_n = sales.select_dtypes(include=np.number)
sales_n.head()
# Out:
#    Amount  Profit  Quantity
# 0    9726    1275         5
# 1    9726    1275         5
# 2    9726    1275         5
# 3    4975    1330        14
# 4    4975    1330        14

# %%
sales_n.columns
# Out:
# Index(['Amount', 'Profit', 'Quantity'], dtype='object')

# %%
sales_c = sales.select_dtypes(include='object')
sales_c.head()
# Out:
#   Order ID     Category      Sub-Category PaymentMode  Order Date  \
# 0  B-26776  Electronics  Electronic Games         UPI  2023-06-27
# 1  B-26776  Electronics  Electronic Games         UPI  2024-12-27
# 2  B-26776  Electronics  Electronic Games         UPI  2021-07-25
# 3  B-26776  Electronics          Printers         UPI  2023-06-27
# 4  B-26776  Electronics          Printers         UPI  2024-12-27
#
#     CustomerName     State     City Year-Month
# 0  David Padilla   Florida    Miami    2023-06
# 1  Connor Morgan  Illinois  Chicago    2024-12
# 2   Robert Stone  New York  Buffalo    2021-07
# 3  David Padilla   Florida    Miami    2023-06
# 4  Connor Morgan  Illinois  Chicago    2024-12

# %%
sns.barplot(x='Category', y='Profit',hue='State', data=sales, palette = 'magma')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.show()

# %%
sub_cat = sales['Sub-Category'].value_counts()
sub_cat.plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
payment_method = sales['PaymentMode'].value_counts()
payment_method.plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# some random orders
order_id = sales['Order ID'].value_counts()
order_id.sample(n=20).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(sales_n)
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Sales')
plt.show()
# Out:
# <ipython-input-19-9a8d15b6dbb4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sales_n)

# %%
sns.distplot(x=sales_n['Amount'], kde=True, color='green')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Amount')
plt.show()
# Out:
# <ipython-input-68-0724a6967dc4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=sales_n['Amount'], kde=True, color='green')

# %%
sns.swarmplot(x='State', y='Amount',hue='PaymentMode', data=sales, palette='crest')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sns.stripplot(x='PaymentMode', y='Amount', hue = 'Category',data=sales, palette='crest')
# Out:
# <Axes: xlabel='PaymentMode', ylabel='Amount'>

# %%
sns.scatterplot(x='Amount', y='Profit', hue='Category', data=sales, palette = 'magma')
plt.xlabel('Amount')
plt.ylabel('Profit')
plt.show()

# %%
sales_n.columns
# Out:
# Index(['Amount', 'Profit', 'Quantity'], dtype='object')

# %%
sns.pairplot(sales, hue='State', diag_kind = 'kde')
plt.show()

# %%
sns.scatterplot(x='Amount', y='Profit', hue='Category', data=sales)
plt.xlabel('Amount')
plt.ylabel('Profit')
plt.title('Amount vs Profit')
plt.show()

# %%
sns.scatterplot(x='Amount', y='Quantity', hue='Category', data=sales)
plt.xlabel('Amount')
plt.ylabel('Quantity')
plt.title('Amount vs Quantity')
plt.show()

# %%
sns.countplot(x='PaymentMode', hue='Sub-Category', data=sales)
# Out:
# <Axes: xlabel='PaymentMode', ylabel='count'>

# %%
sns.countplot(y='State', hue='Sub-Category', data=sales, palette = 'viridis')
plt.xticks(rotation=90)
plt.show()

# %%
sales_c.columns
# Out:
# Index(['Order ID', 'Category', 'Sub-Category', 'PaymentMode', 'Order Date',
#        'CustomerName', 'State', 'City', 'Year-Month'],
#       dtype='object')

# %%
sns.histplot(x='State', hue='Sub-Category', data=sales, palette = 'viridis')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='State', hue='Year-Month', data=sales, palette = 'viridis', legend = False)
plt.xticks(rotation=90)
plt.show()

# %%
group_category_sub = sales.groupby('Sub-Category')['Category'].value_counts()
group_category_sub

group_category_sub.plot(kind='barh')
plt.xlabel('Sub-Category')
plt.ylabel('Category')
plt.title('Category vs Sub-Category')
plt.show()

# %%
sub_yearmonth = sales.groupby('Year-Month')['Sub-Category'].value_counts()
sub_yearmonth

sub_yearmonth.plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Sub-Cat/Year.Month/Value Counts')
plt.yticks([])
plt.title('Sub-Category vs Year-Month')
plt.show()

# %%
order_date_vs_state = sales.groupby('Order Date')['State'].value_counts()
order_date_vs_state


os = order_date_vs_state.head(10)
os.plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Order Date/State/Value Counts')
plt.title('Order Date vs State')
plt.show()

os2 = order_date_vs_state.tail(10)
os2.plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Order Date/State/Value Counts')
plt.title('Order Date vs State')
plt.show()

os3 = order_date_vs_state.sample(10)
os3 = os3.sort_values(ascending=False)
os3.plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Order Date/State/Value Counts')
plt.title('Order Date vs State')
plt.show()

# %%
sales_c.columns
# Out:
# Index(['Order ID', 'Category', 'Sub-Category', 'PaymentMode', 'Order Date',
#        'CustomerName', 'State', 'City', 'Year-Month'],
#       dtype='object')

# %%
sales_c.drop('CustomerName', inplace = True, axis = 1)
# gives error after dropping

# %%
sales_c.head()
# Out:
#   Order ID     Category      Sub-Category PaymentMode  Order Date     State  \
# 0  B-26776  Electronics  Electronic Games         UPI  2023-06-27   Florida
# 1  B-26776  Electronics  Electronic Games         UPI  2024-12-27  Illinois
# 2  B-26776  Electronics  Electronic Games         UPI  2021-07-25  New York
# 3  B-26776  Electronics          Printers         UPI  2023-06-27   Florida
# 4  B-26776  Electronics          Printers         UPI  2024-12-27  Illinois
#
#       City Year-Month
# 0    Miami    2023-06
# 1  Chicago    2024-12
# 2  Buffalo    2021-07
# 3    Miami    2023-06
# 4  Chicago    2024-12

# %%
sales_c_sample = sales_c.sample(500)
sales_c_sample
sns.countplot(y='Year-Month', hue='Sub-Category', data=sales_c_sample, palette = 'viridis')
plt.yticks([
])
plt.show()

# %%
sales_n.columns
# Out:
# Index(['Amount', 'Profit', 'Quantity'], dtype='object')

# %%
sales_n.head(10)
# Out:
#    Amount  Profit  Quantity
# 0    9726    1275         5
# 1    9726    1275         5
# 2    9726    1275         5
# 3    4975    1330        14
# 4    4975    1330        14
# 5    4975    1330        14
# 6    1525     185        12
# 7    1525     185        12
# 8     883     117        10
# 9    8127    3551        16

# %%
sns.histplot(sales_n['Amount'], kde=True)
plt.show()

# %%
sales.columns
# Out:
# Index(['Order ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'PaymentMode', 'Order Date', 'CustomerName', 'State', 'City',
#        'Year-Month'],
#       dtype='object')

# %%
sales.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   PaymentMode  Order Date   CustomerName     State     City Year-Month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
sales_n
# Out:
#       Amount  Profit  Quantity
# 0       9726    1275         5
# 1       9726    1275         5
# 2       9726    1275         5
# 3       4975    1330        14
# 4       4975    1330        14
# ...      ...     ...       ...
# 1189    8825    3594        15
# 1190    2082     642         8
# 1191    2082     642         8
# 1192    2082     642         8
# 1193     914     163        13
#
# [1194 rows x 3 columns]

# %%
sales_c
# Out:
#      Order ID         Category      Sub-Category PaymentMode  Order Date  \
# 0     B-26776      Electronics  Electronic Games         UPI  2023-06-27
# 1     B-26776      Electronics  Electronic Games         UPI  2024-12-27
# 2     B-26776      Electronics  Electronic Games         UPI  2021-07-25
# 3     B-26776      Electronics          Printers         UPI  2023-06-27
# 4     B-26776      Electronics          Printers         UPI  2024-12-27
# ...       ...              ...               ...         ...         ...
# 1189  B-26370        Furniture            Tables  Debit Card  2024-07-31
# 1190  B-26298      Electronics            Phones         EMI  2020-06-02
# 1191  B-26298      Electronics            Phones         EMI  2022-12-15
# 1192  B-26298      Electronics            Phones         EMI  2020-08-07
# 1193  B-25068  Office Supplies           Markers         UPI  2024-10-26
#
#          State           City Year-Month
# 0      Florida          Miami    2023-06
# ...

# %%
sales_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Amount    1194 non-null   int64
#  1   Profit    1194 non-null   int64
#  2   Quantity  1194 non-null   int64
# dtypes: int64(3)
# memory usage: 28.1 KB

# %%
sales_n.describe()
# Out:
#             Amount       Profit     Quantity
# count  1194.000000  1194.000000  1194.000000
# mean   5178.089615  1348.992462    10.674204
# std    2804.921955  1117.992573     5.777102
# min     508.000000    50.000000     1.000000
# 25%    2799.000000   410.000000     6.000000
# 50%    5152.000000  1014.000000    11.000000
# 75%    7626.000000  2035.000000    16.000000
# max    9992.000000  4930.000000    20.000000

# %%
corr = sales_n.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8315f_row0_col0, #T_8315f_row1_col1, #T_8315f_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8315f_row0_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_8315f_row0_col2, #T_8315f_row2_col0, #T_8315f_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8315f_row1_col0 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_8315f_row1_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8315f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8315f_level0_col0" class="col_heading level0 col0" >Amount</th>
#       <th id="T_8315f_level0_col1" class="col_heading level0 col1" >Profit</th>
#       <th id="T_8315f_level0_col2" class="col_heading level0 col2" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8315f_level0_row0" class="row_heading level0 row0" >Amount</th>
# ...

# %%
sns.heatmap(corr, annot=True, cmap = 'magma')
plt.show()

# %%
sns.pairplot(sales_n, diag_kind= 'kde')
plt.show()

# %%
sales_n.columns
# Out:
# Index(['Amount', 'Profit', 'Quantity'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


x = sales_n.drop('Profit', axis=1)
y = sales_n['Profit']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 Score:', r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 688303.018185324
# R2 Score: 0.4567601812280654

# %%
sns.lineplot(x=y_test, y=y_pred)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Actual vs Predicted Profit')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
sales_c['State'] = encoder.fit_transform(sales_c['State'])
sales_c['Category'] = encoder.fit_transform(sales_c['Category'])
sales_c['Sub-Category'] = encoder.fit_transform(sales_c['Sub-Category'])
sales_c['PaymentMode'] = encoder.fit_transform(sales_c['PaymentMode'])
sales_c['Year-Month'] = encoder.fit_transform(sales_c['Year-Month'])

# %%
sales_c['State'].plot(kind='hist', bins=20)
plt.xlabel('State')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sales_c = sales_c.sample(30)
sales_c['Category'].plot(kind='pie' )
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %%
sales_c['State'] = encoder.inverse_transform(sales_c['State']) # Apply inverse_transform to the dedicated encoder
sales_c

sales_c['Category'] = encoder.inverse_transform(sales_c['Category'])
sales_c

sales_c['Sub-Category'] = encoder.inverse_transform(sales_c['Sub-Category'])
sales_c

sales_c['PaymentMode'] = encoder.inverse_transform(sales_c['PaymentMode'])
sales_c

sales_c['Year-Month'] = encoder.inverse_transform(sales_c['Year-Month'])
sales_c

sales_c.head()
# Out:
#     Order ID Category Sub-Category PaymentMode  Order Date    State  \
# 291  B-26969  2020-05      2020-10     2020-05  2021-04-30  2020-06
# 748  B-25465  2020-04      2021-02     2020-04  2023-10-24  2020-06
# 966  B-25441  2020-04      2021-01     2020-04  2024-06-08  2020-06
# 272  B-26322  2020-05      2020-08     2020-06  2024-09-06  2020-05
# 704  B-25517  2020-04      2020-04     2020-06  2021-12-29  2020-06
#
#           City Year-Month
# 291  Rochester    2021-04
# 748  Rochester    2023-10
# 966  Rochester    2024-06
# 272     Peoria    2024-09
# 704    Buffalo    2021-12

# %%
sales_c.head()
# Out:
#     Order ID Category Sub-Category PaymentMode  Order Date    State  \
# 291  B-26969  2020-05      2020-10     2020-05  2021-04-30  2020-06
# 748  B-25465  2020-04      2021-02     2020-04  2023-10-24  2020-06
# 966  B-25441  2020-04      2021-01     2020-04  2024-06-08  2020-06
# 272  B-26322  2020-05      2020-08     2020-06  2024-09-06  2020-05
# 704  B-25517  2020-04      2020-04     2020-06  2021-12-29  2020-06
#
#           City Year-Month
# 291  Rochester    2021-04
# 748  Rochester    2023-10
# 966  Rochester    2024-06
# 272     Peoria    2024-09
# 704    Buffalo    2021-12

# %%
sales_n.columns
# Out:
# Index(['Amount', 'Profit', 'Quantity'], dtype='object')

# %%
sales = pd.read_csv('Sales Dataset.csv')
sales.head()

sales.drop('CustomerName', inplace = True, axis = 1)
sales.head()

sales_n = sales.select_dtypes(include=np.number)
sales_n.head()

sales_c = sales.select_dtypes(include='object')
sales_c.head()

sales_c

sales_n.dropna(inplace=True)
sales_c.dropna(inplace=True)

# %%
sales_n.head()
# Out:
#    Amount  Profit  Quantity
# 0    9726    1275         5
# 1    9726    1275         5
# 2    9726    1275         5
# 3    4975    1330        14
# 4    4975    1330        14

# %%
sales_c.head()
# Out:
#   Order ID     Category      Sub-Category PaymentMode  Order Date     State  \
# 0  B-26776  Electronics  Electronic Games         UPI  2023-06-27   Florida
# 1  B-26776  Electronics  Electronic Games         UPI  2024-12-27  Illinois
# 2  B-26776  Electronics  Electronic Games         UPI  2021-07-25  New York
# 3  B-26776  Electronics          Printers         UPI  2023-06-27   Florida
# 4  B-26776  Electronics          Printers         UPI  2024-12-27  Illinois
#
#       City Year-Month
# 0    Miami    2023-06
# 1  Chicago    2024-12
# 2  Buffalo    2021-07
# 3    Miami    2023-06
# 4  Chicago    2024-12

# %%
sales_c.drop('Order ID', inplace = True, axis = 1)
#dropped

# %%
sales_n.columns
# Out:
# Index(['Amount', 'Profit', 'Quantity'], dtype='object')

# %%
sns.stripplot(x='State', y='Amount', data=sales, palette='crest')
# Out:
# <ipython-input-62-c9b2ff1fc4d5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='State', y='Amount', data=sales, palette='crest')
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sns.swarmplot(x='State', y='Amount', data=sales,hue='Sub-Category', palette='magma')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sales_n = sales_n[sales_n['Amount'] > 0]

# %%
sns.kdeplot(x='Amount', y='Profit', data=sales, hue='Category', palette='magma')
plt.show()
